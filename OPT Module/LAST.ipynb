# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import glob
import pandas as pd

# %%
pwd
# Out:
# '/Users/HimeshNag/Desktop/1.project/Wave - Analysis:plot'

# %%
cd ..
# Out:
# /Users/HimeshNag/Desktop/1.project

# %%
data, sampling_rate = librosa.load("l12.wav")

# %%
plt.figure(figsize=(20, 5))
librosa.display.waveplot(data, sr=sampling_rate)
